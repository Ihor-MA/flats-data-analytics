# %%
import numpy as np
import pandas as pd

df = pd.read_csv('flats.csv')
df.index = np.arange(1, len(df) + 1)
df.head()
# Out:
#      city           region                              address      price  \
# 1  Харків  Холодногірський             вул. Болбочана Петра, 52  180 000 $
# 2    Київ              NaN              вул. Предславинська, 42  479 000 $
# 3    Київ    Голосіївський        просп. Академіка Глушкова, 9Є   76 000 $
# 4    Київ   Шевченківський  просп. Берестейський(Перемоги), 42А  213 500 $
# 5    Київ       Дарницький                наб. Дніпровська, 14Б  360 000 $
#
#   price_for_square_metre total_area floor  num_of_floors  num_of_rooms  \
# 1                1 552 $     116 м²     9           10.0           3.0
# 2                5 885 $    81.4 м²    22           24.0           2.0
# 3                1 551 $      50 м²    18           25.0           1.0
# 4                2 200 $    97.6 м²     7           23.0           2.0
# 5                3 273 $     110 м²     7           23.0           3.0
#
#          subway         apartment_complex
# 1  Холодна гора                       NaN
# ...
